# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import torch

x = torch.arange(0,3,0.01)
y = torch.sin(x)
y2 = torch.cos(x)

plt.plot(x,y[0:50],color="blue", linewidth=2.5, linestyle="-", label="cosine")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_70509/3183750822.py in <module>
#       7 y2 = torch.cos(x)
#       8
# ----> 9 plt.plot(x,y[0:50],color="blue", linewidth=2.5, linestyle="-", label="cosine")
#
# ~/Applications/YOLOX/demo/MegEngine/PVMegengine/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/Applications/YOLOX/demo/MegEngine/PVMegengine/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
# ...

# %%
import torch
from torch import nn
loss = torch.nn.CrossEntropyLoss()
loss(1,22)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_26914/847056457.py in <module>
#       2 from torch import nn
#       3 loss = torch.nn.CrossEntropyLoss()
# ----> 4 loss(1,22)
#       5
#
# ~/Applications/YOLOX/demo/MegEngine/PVMegengine/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/Applications/YOLOX/demo/MegEngine/PVMegengine/lib/python3.8/site-packages/torch/nn/modules/loss.py in forward(self, input, target)
#    1045     def forward(self, input: Tensor, target: Tensor) -> Tensor:
# ...
